# %% [markdown]
# # UTSA CS 3793: Assignment-4
#
# **Figueroa - Fabian - sop310**

# %% [markdown]
# ## Learning Objectives
#
# *   Deep Learning
# *   Computer Vision - Convolutional Neural Network
# *   Natural Language Processing - Recurrent Neural Network

# %% [markdown]
# ## General Information
#
# The base structure and comments are provided on what should be done. You are free to use any code from online sources, but please cite the source properly. Also, you are supposed to create/train the DL model and not use pre-trained models.
#
# **TIPS** while working on this assignment:
#
#
# *   You will have to keep on updating the model to improve accuracy. Hence, all except the first step (loading the data) would be repeated multiple times. i.e. repeat -- model creation, training & testing.
# *   Training a Deep Learning model on real-world datasets and obtain decent accuracy is time consuming. For this assignment, it may take at least 40-60 min, if not more, to train the complete data and get around 35% testing accuracy. Hence, have enough time planned out for finishing the assignment.
# *   Because of the large training time, it is impossisble to train each student's model. Hence, you will be required to **save the weights** in a file. These weights can then be loaded for testing purposes. More information is provided in a TensorFlow tutorial [here](https://www.tensorflow.org/tutorials/keras/save_and_load).
# *   Please refer to the [TensorFlow Keras API](https://www.tensorflow.org/api_docs/python/tf/keras) for selecting the *'activation function', 'loss', 'optimizer' & 'metrics'*. At least use 'accuracy' as one of the 'metrics'.

# %% [markdown]
# ##Import Libraries
#
# Write all the import statements here.

# %%
# importing all required libraries
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ERROR:absl:Detected incompatible Protobuf Gencode/Runtime versions when loading tensorflow_metadata/proto/v0/anomalies.proto: gencode 6.31.1 runtime 5.29.6. Runtime version cannot be older than the linked gencode version. See Protobuf version guarantees at https://protobuf.dev/support/cross-version-runtime-guarantee.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/__init__.py", line 79, in <module>
#     from tensorflow_datasets import rlds  # pylint: disable=g-bad-import-order
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/rlds/__init__.py", line 21, in <module>
#     from tensorflow_datasets.rlds import envlogger_reader
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/rlds/envlogger_reader.py", line 21, in <module>
#     from tensorflow_datasets.core.utils.lazy_imports_utils import tree
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/__init__.py", line 21, in <module>
#     from tensorflow_datasets.core import community
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/community/__init__.py", line 19, in <module>
#     from tensorflow_datasets.core.community.huggingface_wrapper import mock_builtin_to_use_gfile
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/community/huggingface_wrapper.py", line 32, in <module>
#     from tensorflow_datasets.core import dataset_builder
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/dataset_builder.py", line 162, in <module>
#     class DatasetBuilder(registered.RegisteredDataset):
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/etils/epy/lazy_imports_utils.py", line 123, in __getattr__
#     return getattr(self._module, name)
#                    ^^^^^^^^^^^^
#   File "/usr/lib/python3.12/functools.py", line 998, in __get__
#     val = self.func(instance)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/etils/epy/lazy_imports_utils.py", line 84, in _module
#     module = importlib.import_module(self.module_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/registered.py", line 36, in <module>
#     import tensorflow_datasets.core.logging as _tfds_logging
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/logging/__init__.py", line 29, in <module>
#     from tensorflow_datasets.core.logging import logging_logger
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/logging/logging_logger.py", line 21, in <module>
#     from tensorflow_datasets.core import decode
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/decode/__init__.py", line 22, in <module>
#     from tensorflow_datasets.core.decode.partial_decode import PartialDecoding
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/decode/partial_decode.py", line 21, in <module>
#     from tensorflow_datasets.core import features as features_lib
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/features/__init__.py", line 22, in <module>
#     from tensorflow_datasets.core.features.audio_feature import Audio
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/features/audio_feature.py", line 33, in <module>
#     from tensorflow_datasets.core.features import feature as feature_lib
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/features/feature.py", line 36, in <module>
#     from tensorflow_datasets.core.proto import feature_pb2
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/proto/__init__.py", line 18, in <module>
#     from tensorflow_datasets.core.proto import dataset_info_generated_pb2 as dataset_info_pb2  # pylint: disable=line-too-long
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/core/proto/dataset_info_generated_pb2.py", line 32, in <module>
#     from tensorflow_metadata.proto.v0 import schema_pb2 as tensorflow__metadata_dot_proto_dot_v0_dot_schema__pb2
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_metadata/proto/__init__.py", line 16, in <module>
#     from tensorflow_metadata.proto.v0 import (
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_metadata/proto/v0/anomalies_pb2.py", line 12, in <module>
#     _runtime_version.ValidateProtobufRuntimeVersion(
#   File "/usr/local/lib/python3.12/dist-packages/google/protobuf/runtime_version.py", line 100, in ValidateProtobufRuntimeVersion
#     _ReportVersionError(
#   File "/usr/local/lib/python3.12/dist-packages/google/protobuf/runtime_version.py", line 50, in _ReportVersionError
#     raise VersionError(msg)
# google.protobuf.runtime_version.VersionError: Detected incompatible Protobuf Gencode/Runtime versions when loading tensorflow_metadata/proto/v0/anomalies.proto: gencode 6.31.1 runtime 5.29.6. Runtime version cannot be older than the linked gencode version. See Protobuf version guarantees at https://protobuf.dev/support/cross-version-runtime-guarantee.
# Mounted at /content/drive

# %% [markdown]
# # Computer Vision - CNN
#
# The goal of this task is to get hands-on experience in developing, training and testing **Convolutional Neural Network** for the Computer Vision task of Object/Image Classification.

# %% [markdown]
# ## Load/Prepare Data
#
# (20 points)
#
# In this assignment, will work with the well-known **CIFAR-100 dataset**. The dataset consists of 60000 32x32 color images, which belong to 100 classes, with 600 images per class. There are 50000 training images (500 per class) and 10000 test images (100 per class). The 100 classes in the dataset are grouped into 20 superclasses. Each image comes with a "fine" label (the class to which it belongs) and a "coarse" label (the superclass to which it belongs). More information about the dataset can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html). Please visit this [website](https://benchmarks.ai/cifar-100) for the benchmark performances of different techniques on the CIFAR-100 dataset.
#
# In this section, you will write code for the following:
#
# *   Load the CIFAR-100 dataset
# *   Prepare the data to be used for the DL model creation and training
# *   Visualize the data by plotting 100 random images, one each for the 100 classes

# %%
# !mkdir -p ~/.keras/datasets
# !cp -r /content/drive/MyDrive/Colab\ Notebooks/cifar/cache/cifar-100-python-target* ~/.keras/datasets
# !ls ~/.keras/datasets
# Out:
# cifar-100-python-target  cifar-100-python-target_archive

# %%
# Load the data - training as well as testing
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data()

# Prepare the data that can be used by the next step - creating and training the DL model
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
'''
print(x_train.dtype)
print(x_test.dtype)
print(x_test.max())
'''
y_train = y_train.flatten()
y_test = y_test.flatten()

print(y_train.shape)
print(y_test.shape)

# The data from TensforFlow and Keras will only have integer class labels. Each of those 100 integer class labels correspond to the following names, in the correct order
fine_labels = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']

# These are the string labels for the 20 superclasses. You may not need to use this at all, just provided here for reference.
coarse_labels = ['aquatic_mammals', 'fish', 'flowers', 'food_containers', 'fruit_and_vegetables', 'household_electrical_devices', 'household_furniture', 'insects', 'large_carnivores', 'large_man-made_outdoor_things', 'large_natural_outdoor_scenes', 'large_omnivores_and_herbivores', 'medium_mammals', 'non-insect_invertebrates', 'people', 'reptiles', 'small_mammals', 'trees', 'vehicles_1', 'vehicles_2']
# Out:
# (50000,)
# (10000,)

# %%
# Visualize the data by plotting 100 random images, one each for the 100 classes

plt.figure(figsize=(15,15))
for i in range(100):
  indices = np.where(y_train == i)[0]
  random_index = np.random.choice(indices)
  image = x_train[random_index]
  label = fine_labels[i]
  plt.subplot(10,10,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(image)
  plt.xlabel(label)
plt.show()

# %% [markdown]
# ## CNN Model Creation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Create a DL model for Computer Vision - Convolutional Neural Network (Use *TensorFlow* and *keras*, as shown in the example code in the lecture for 'deep-learning')
# *   Print the DL model summary

# %%
# Create a DL model for Computer Vision - Convolutional Neural Network (Use *TensorFlow* and *keras*, as shown in the example code in the lecture for 'deep-learning')
def create_model():
  model = keras.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(x_train.shape[1], x_train.shape[2], x_train.shape[3])),
    keras.layers.MaxPooling2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(len(np.unique(y_train)), activation='softmax')
  ])
  model.compile(
        optimizer='SGD',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
        )
  return model

# %%
# Print the DL model summary
cifar_model = create_model()
print(cifar_model.summary())
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100)            │       230,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        10,100 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 259,992 (1015.59 KB)
#  Trainable params: 259,992 (1015.59 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Training
#
# (15 points)
#
# In this section, you will write code to do the following:
#
# *   Train/fit the DL model using the training CIFAR-100 data
# *   Plot the training/validation accuracy and loss
# *   *Save the trained model weights* in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/cifar/", to be used for the testing phase

# %%
# Set the model checkpoints to be saved in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/cifar/"
cp_callback = keras.callbacks.ModelCheckpoint(filepath="/content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5",
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
# Train/fit the DL model using the training CIFAR-100 data
history = cifar_model.fit(x_train, y_train, epochs=50, batch_size=64, validation_split=0.2, callbacks=[cp_callback])
# Out:
# Epoch 1/50
# 613/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2479 - loss: 3.1329
# Epoch 1: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2516 - loss: 3.1184 - val_accuracy: 0.2315 - val_loss: 3.2324
# Epoch 2/50
# 615/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2640 - loss: 3.0661
# Epoch 2: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2626 - loss: 3.0567 - val_accuracy: 0.2449 - val_loss: 3.1746
# Epoch 3/50
# 604/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2723 - loss: 3.0059
# Epoch 3: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 3: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2748 - loss: 2.9975 - val_accuracy: 0.2559 - val_loss: 3.1202
# Epoch 4/50
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2833 - loss: 2.9441
# Epoch 4: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 4: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2837 - loss: 2.9464 - val_accuracy: 0.2553 - val_loss: 3.1104
# Epoch 5/50
# 617/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2916 - loss: 2.9138
# Epoch 5: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2944 - loss: 2.8920 - val_accuracy: 0.2691 - val_loss: 3.0651
# Epoch 6/50
# 603/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3058 - loss: 2.8301
# Epoch 6: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 6: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3046 - loss: 2.8390 - val_accuracy: 0.2713 - val_loss: 3.0279
# Epoch 7/50
# 615/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3122 - loss: 2.7948
# Epoch 7: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 7: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3122 - loss: 2.7923 - val_accuracy: 0.2676 - val_loss: 3.0589
# Epoch 8/50
# 614/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3231 - loss: 2.7404
# Epoch 8: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 8: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3214 - loss: 2.7481 - val_accuracy: 0.2836 - val_loss: 2.9830
# Epoch 9/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3346 - loss: 2.7013
# Epoch 9: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 9: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3322 - loss: 2.7073 - val_accuracy: 0.2876 - val_loss: 2.9837
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3411 - loss: 2.6511
# Epoch 10: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 10: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3386 - loss: 2.6642 - val_accuracy: 0.2829 - val_loss: 3.0001
# Epoch 11/50
# 613/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3509 - loss: 2.6080
# Epoch 11: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 11: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3473 - loss: 2.6259 - val_accuracy: 0.2951 - val_loss: 2.9366
# Epoch 12/50
# 615/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3551 - loss: 2.5934
# Epoch 12: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 12: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3532 - loss: 2.5900 - val_accuracy: 0.2858 - val_loss: 2.9881
# Epoch 13/50
# 610/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3598 - loss: 2.5627
# Epoch 13: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 13: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3613 - loss: 2.5573 - val_accuracy: 0.2980 - val_loss: 2.9263
# Epoch 14/50
# 607/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3670 - loss: 2.5209
# Epoch 14: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 14: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3683 - loss: 2.5235 - val_accuracy: 0.2996 - val_loss: 2.9313
# Epoch 15/50
# 610/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3790 - loss: 2.4721
# Epoch 15: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 15: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3749 - loss: 2.4882 - val_accuracy: 0.3127 - val_loss: 2.8577
# Epoch 16/50
# 608/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3811 - loss: 2.4477
# Epoch 16: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 16: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3804 - loss: 2.4573 - val_accuracy: 0.3124 - val_loss: 2.8614
# Epoch 17/50
# 620/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3917 - loss: 2.4183
# Epoch 17: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 17: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3884 - loss: 2.4276 - val_accuracy: 0.3164 - val_loss: 2.8455
# Epoch 18/50
# 617/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3974 - loss: 2.3800
# Epoch 18: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 18: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3941 - loss: 2.3945 - val_accuracy: 0.3140 - val_loss: 2.8414
# Epoch 19/50
# 619/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4038 - loss: 2.3491
# Epoch 19: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 19: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4017 - loss: 2.3636 - val_accuracy: 0.3197 - val_loss: 2.8346
# Epoch 20/50
# 605/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4102 - loss: 2.3138
# Epoch 20: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 20: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4094 - loss: 2.3323 - val_accuracy: 0.3190 - val_loss: 2.8520
# Epoch 21/50
# 602/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4232 - loss: 2.2766
# Epoch 21: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 21: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4180 - loss: 2.3016 - val_accuracy: 0.3283 - val_loss: 2.8004
# Epoch 22/50
# 612/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4259 - loss: 2.2655
# Epoch 22: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 22: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4225 - loss: 2.2704 - val_accuracy: 0.3207 - val_loss: 2.8176
# Epoch 23/50
# 605/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4290 - loss: 2.2304
# Epoch 23: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 23: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4266 - loss: 2.2445 - val_accuracy: 0.3287 - val_loss: 2.8252
# Epoch 24/50
# 612/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4329 - loss: 2.2153
# Epoch 24: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 24: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4320 - loss: 2.2140 - val_accuracy: 0.3278 - val_loss: 2.7975
# Epoch 25/50
# 614/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4448 - loss: 2.1603
# Epoch 25: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 25: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4383 - loss: 2.1868 - val_accuracy: 0.3354 - val_loss: 2.7743
# Epoch 26/50
# 607/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4490 - loss: 2.1516
# Epoch 26: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 26: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4465 - loss: 2.1561 - val_accuracy: 0.3355 - val_loss: 2.7959
# Epoch 27/50
# 603/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4612 - loss: 2.0952
# Epoch 27: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 27: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4524 - loss: 2.1277 - val_accuracy: 0.3306 - val_loss: 2.7987
# Epoch 28/50
# 617/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4660 - loss: 2.0833
# Epoch 28: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 28: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4604 - loss: 2.1010 - val_accuracy: 0.3359 - val_loss: 2.7774
# Epoch 29/50
# 605/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4748 - loss: 2.0336
# Epoch 29: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 29: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4645 - loss: 2.0731 - val_accuracy: 0.3323 - val_loss: 2.7911
# Epoch 30/50
# 608/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4758 - loss: 2.0281
# Epoch 30: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 30: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4726 - loss: 2.0478 - val_accuracy: 0.3362 - val_loss: 2.7799
# Epoch 31/50
# 620/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4843 - loss: 1.9935
# Epoch 31: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 31: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4777 - loss: 2.0183 - val_accuracy: 0.3389 - val_loss: 2.7824
# Epoch 32/50
# 614/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4896 - loss: 1.9634
# Epoch 32: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 32: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4826 - loss: 1.9868 - val_accuracy: 0.3353 - val_loss: 2.8243
# Epoch 33/50
# 607/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4971 - loss: 1.9304
# Epoch 33: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 33: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4904 - loss: 1.9609 - val_accuracy: 0.3300 - val_loss: 2.8372
# Epoch 34/50
# 616/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4996 - loss: 1.9117
# Epoch 34: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 34: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4931 - loss: 1.9360 - val_accuracy: 0.3425 - val_loss: 2.8195
# Epoch 35/50
# 615/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5034 - loss: 1.9008
# Epoch 35: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 35: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5000 - loss: 1.9083 - val_accuracy: 0.3486 - val_loss: 2.7861
# Epoch 36/50
# 620/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5098 - loss: 1.8659
# Epoch 36: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 36: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5082 - loss: 1.8826 - val_accuracy: 0.3344 - val_loss: 2.8537
# Epoch 37/50
# 612/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5163 - loss: 1.8281
# Epoch 37: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 37: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5123 - loss: 1.8528 - val_accuracy: 0.3408 - val_loss: 2.8112
# Epoch 38/50
# 615/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5232 - loss: 1.8041
# Epoch 38: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 38: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5175 - loss: 1.8284 - val_accuracy: 0.3417 - val_loss: 2.8432
# Epoch 39/50
# 612/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5268 - loss: 1.7930
# Epoch 39: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 39: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5243 - loss: 1.8020 - val_accuracy: 0.3456 - val_loss: 2.8148
# Epoch 40/50
# 619/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5423 - loss: 1.7413
# Epoch 40: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 40: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5314 - loss: 1.7733 - val_accuracy: 0.3464 - val_loss: 2.8317
# Epoch 41/50
# 607/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5428 - loss: 1.7145
# Epoch 41: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 41: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5365 - loss: 1.7447 - val_accuracy: 0.3441 - val_loss: 2.8727
# Epoch 42/50
# 610/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5509 - loss: 1.6979
# Epoch 42: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 42: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5438 - loss: 1.7185 - val_accuracy: 0.3387 - val_loss: 2.8771
# Epoch 43/50
# 611/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5521 - loss: 1.6830
# Epoch 43: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 43: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5502 - loss: 1.6978 - val_accuracy: 0.3484 - val_loss: 2.8507
# Epoch 44/50
# 617/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5620 - loss: 1.6474
# Epoch 44: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 44: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5542 - loss: 1.6674 - val_accuracy: 0.3453 - val_loss: 2.8957
# Epoch 45/50
# 614/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5715 - loss: 1.6021
# Epoch 45: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 45: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5594 - loss: 1.6448 - val_accuracy: 0.3504 - val_loss: 2.8779
# Epoch 46/50
# 608/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5741 - loss: 1.5914
# Epoch 46: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 46: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5683 - loss: 1.6138 - val_accuracy: 0.3478 - val_loss: 2.8881
# Epoch 47/50
# 605/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5833 - loss: 1.5575
# Epoch 47: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 47: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5742 - loss: 1.5913 - val_accuracy: 0.3473 - val_loss: 2.9225
# Epoch 48/50
# 608/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5911 - loss: 1.5232
# Epoch 48: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 48: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5786 - loss: 1.5668 - val_accuracy: 0.3395 - val_loss: 2.9640
# Epoch 49/50
# 613/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5932 - loss: 1.5166
# Epoch 49: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 49: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5872 - loss: 1.5369 - val_accuracy: 0.3437 - val_loss: 2.9852
# Epoch 50/50
# 614/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6026 - loss: 1.4820
# Epoch 50: saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
#
# Epoch 50: finished saving model to /content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5943 - loss: 1.5132 - val_accuracy: 0.3452 - val_loss: 2.9896

# %%
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Plot the training/validation accuracy and loss

plt.figure(figsize=(12,5))

# accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training/Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training/Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Testing/Evaluation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Re-initialize the model
# *   Load the model weights that were saved at "/content/drive/My Drive/Colab Notebooks/cifar/" ([code reference](https://www.tensorflow.org/tutorials/keras/save_and_load))
# *   Evaluate the trained DL model on the CIFAR-100 test dataset. Accuracy value should be printed. Please visit this [website](https://benchmarks.ai/cifar-100) for the benchmark performances of different techniques on the CIFAR-100 dataset.
#
# This section of the code should be able to run independently from the **training** section, i.e. run this section directly after creating the model.

# %%
# Re-initialize the model
cifar_model = create_model()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Load the model weights that were saved at - "/content/drive/My Drive/Colab Notebooks/cifar/"
cifar_model.load_weights('/content/drive/My Drive/Colab Notebooks/cifar/cifar_model.weights.h5')

# %%
# Evaluate the trained DL model on the CIFAR-100 test dataset
cifar_model.evaluate(x_test, y_test, batch_size=64)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3548 - loss: 2.9465
# [2.9465086460113525, 0.3547999858856201]

# %% [markdown]
# # Natural Language Processing - RNN
#
# The goal of this task is to get hands-on experience in developing, training and testing **Recurrent Neural Network** for the Natural Language Processing task of Sentiment Analysis / Text Classification. In this part, you will work with the well-known **Reuters newswire classification dataset**. The dataset consists of newswires from Reuters, labeled over 46 topics. More information about the dataset can be found [here](https://archive.ics.uci.edu/ml/datasets/reuters-21578+text+categorization+collection) or [here](https://keras.io/api/datasets/reuters/). The Keras dataset is a cleaned and organized version of the original dataset and consists of 11,228 newswires (8982 training and 2246 testing). The goal is to classify a newswire into one of the 46 output catergories.

# %% [markdown]
# ## Load/Prepare Data
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Load the Reuters dataset - use the Keras version
#  *   Select the vocabulary size while loading the data
#  *   The data will be loaded as integer representations for each word
# *   Prepare the data to be used for the next steps
#  *   Each data entry (newswire) can be of different lengths
#  *   Make each newswire consistent - same number of words
#  *   'Pad' words (say 0) to get to the standard length or remove words

# %%
# Load the Reuters dataset - use the Keras version
#   Select the vocabulary size while loading the data
#   The data will be loaded as integer representations for each word

(x_train, y_train), (x_test, y_test) = keras.datasets.reuters.load_data( path="reuters.npz", num_words=10000)

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
print(x_train[0])
# Out:
# (8982,) (8982,) (2246,) (2246,)
# [1, 2, 2, 8, 43, 10, 447, 5, 25, 207, 270, 5, 3095, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 4579, 1005, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 1245, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12]

# %%
print(y_train[0])
print(y_train[1])
print(y_train.shape)
# Out:
# 3
# 4
# (8982,)

# %%
# Prepare the data to be used for the next steps
#   Each data entry (newswire) can be of different lengths
#   Make each newswire consistent - same number of words
#   'Pad' words (say 0) to get to the standard length or remove words
lengths = [len(x) for x in x_train]

x_train = keras.preprocessing.sequence.pad_sequences(x_train, maxlen=int(np.mean(lengths)))
x_test = keras.preprocessing.sequence.pad_sequences(x_test, maxlen=int(np.mean(lengths)))

print(x_train.shape, x_test.shape)
# Out:
# (8982, 145) (2246, 145)

# %% [markdown]
# ## RNN Model Creation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Create a DL model for Natural Language Processing - Recurrent Neural Network / LSTM / GRU
# *   Print the DL model summary

# %%
# Create a DL model for Natural Language Processing - Recurrent Neural Network / LSTM / GRU
def create_model():
  model = keras.Sequential([
      keras.layers.Input(shape=(x_train.shape[1],)),
    keras.layers.Embedding(input_dim=10000, output_dim=128),
    keras.layers.LSTM(units=64),
    keras.layers.Dense(len(np.unique(y_train)), activation='softmax')
  ])
  model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
        )
  return model

# %%
# Print the DL model summary
reuters_model = create_model()
print(reuters_model.summary())
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ (None, 145, 128)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 46)             │         2,990 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,332,398 (5.08 MB)
#  Trainable params: 1,332,398 (5.08 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Training
#
# (15 points)
#
# In this section, you will write code to do the following:
#
# *   Train/fit the DL model using the training Reuters data
# *   Plot the training/validation accuracy and loss
# *   *Save the trained model weights* in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/reuters/" ([code reference](https://www.tensorflow.org/tutorials/keras/save_and_load)), to be used for the testing phase

# %%
# !mkdir -p "/content/drive/My Drive/Colab Notebooks/reuters/"
# !ls "/content/drive/My Drive/Colab Notebooks/"
# Out:
# 'Artificial Intelligence'	        PythonPrimer.ipynb
#  Assigment4.ipynb		        reuters
#  Assignment5.ipynb		        Untitled
#  btt-valley-consolidated.ipynb	        Untitled0.ipynb
#  cifar				       'Untitled (1)'
#  CS3793_assignment1_sop310.ipynb        Untitled1.ipynb
# 'CS3793_assignment2_sop310 (1).ipynb'  'Untitled (2)'
#  CS3793_assignment2_sop310.ipynb        Untitled2.ipynb
#  CS3793_assignment3_sop310.ipynb       'Untitled (3)'
#  CS3793_assignment4_abc123.ipynb       'Untitled (4)'
#  Project1.ipynb

# %%
# Set the model checkpoints to be saved in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/reuters/"
cp_callback = keras.callbacks.ModelCheckpoint(filepath="/content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5",
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
# Train/fit the DL model using the training Reuters data
history = reuters_model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.2, callbacks=[cp_callback])
# Out:
# Epoch 1/10
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4747 - loss: 2.1223
# Epoch 1: saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4834 - loss: 2.1047 - val_accuracy: 0.5025 - val_loss: 1.9958
# Epoch 2/10
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5212 - loss: 1.9075
# Epoch 2: saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5358 - loss: 1.8371 - val_accuracy: 0.5420 - val_loss: 1.7902
# Epoch 3/10
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5899 - loss: 1.6376
# Epoch 3: saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
#
# Epoch 3: finished saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6113 - loss: 1.5789 - val_accuracy: 0.6266 - val_loss: 1.5377
# Epoch 4/10
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6608 - loss: 1.3713
# Epoch 4: saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
#
# Epoch 4: finished saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6608 - loss: 1.3632 - val_accuracy: 0.5927 - val_loss: 1.5425
# Epoch 5/10
# 108/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6986 - loss: 1.1900
# Epoch 5: saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7079 - loss: 1.1633 - val_accuracy: 0.6650 - val_loss: 1.3749
# Epoch 6/10
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7548 - loss: 0.9741
# Epoch 6: saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
#
# Epoch 6: finished saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7587 - loss: 0.9615 - val_accuracy: 0.6889 - val_loss: 1.3470
# Epoch 7/10
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7893 - loss: 0.8466
# Epoch 7: saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
#
# Epoch 7: finished saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7912 - loss: 0.8378 - val_accuracy: 0.6956 - val_loss: 1.3606
# Epoch 8/10
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8267 - loss: 0.7067
# Epoch 8: saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
#
# Epoch 8: finished saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8315 - loss: 0.6830 - val_accuracy: 0.6889 - val_loss: 1.3547
# Epoch 9/10
# 108/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8573 - loss: 0.5890
# Epoch 9: saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
#
# Epoch 9: finished saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8653 - loss: 0.5686 - val_accuracy: 0.7051 - val_loss: 1.3625
# Epoch 10/10
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8851 - loss: 0.4776
# Epoch 10: saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
#
# Epoch 10: finished saving model to /content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8862 - loss: 0.4817 - val_accuracy: 0.6978 - val_loss: 1.3878

# %%
# Plot the training/validation accuracy and loss

plt.figure(figsize=(12,5))

# accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training/Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training/Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Testing/Evaluation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Re-initialize the model
# *   Load the model weights that were saved at "/content/drive/My Drive/Colab Notebooks/reuters/" ([code reference](https://www.tensorflow.org/tutorials/keras/save_and_load))
# *   Evaluate the trained DL model on the Reuters test dataset. Accuracy value should be printed.
#
# This section of the code should be able to run independently from the **training** section, i.e., run this section directly after creating the model.

# %%
# Re-initialize the model
reuters_model = create_model()

# %%
# Load the model weights that were saved at - "/content/drive/My Drive/Colab Notebooks/reuters/"
reuters_model.load_weights('/content/drive/My Drive/Colab Notebooks/reuters/reuters_model.weights.h5')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Evaluate the trained DL model on the Reuters test dataset
reuters_model.evaluate(x_test, y_test, batch_size=64)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6799 - loss: 1.5101
# [1.5101276636123657, 0.6798753142356873]

# %% [markdown]
# # Submission Instructions
#
# 1.   Complete all tasks above - **File MUST contain the output for ALL cells**
# 2.   Export this notebook as .ipynb
#       (File > Download as ipynb)
# 3.   Download and zip the folders "/content/drive/My Drive/Colab Notebooks/cifar/" (abc123_cifar_model.zip) and "/content/drive/My Drive/Colab Notebooks/reuters/" (abc123_reuters_model.zip)
# 4.   Upload the .ipynb file and .zip on Blackboard

# %% [markdown]
# ## Rubric
#
# *   Computer Vision - CNN
#     *   (20 points) Load/Prepare Data
#     *   (15 points) CNN Model Creation
#     *   (15 points) Training
#     *   (15 points) Testing/Evaluation
# *   Natural Language Processing - RNN
#     *   (15 points) Load/Prepare Data
#     *   (15 points) RNN Model Creation
#     *   (15 points) Training
#     *   (15 points) Testing/Evaluation
