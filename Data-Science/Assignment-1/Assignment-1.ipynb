# %%
# Colab setup: install common packages and mount Google Drive when running in Colab
import sys
if 'google.colab' in sys.modules:
    get_ipython().system('pip install -q numpy pandas matplotlib seaborn scikit-learn')
    from google.colab import drive
    drive.mount('/content/drive')
else:
    print('Not running in Colab — skipping Colab-specific setup')

# %%
import numpy as np
